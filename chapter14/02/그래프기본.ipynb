# %% [markdown]
# ### matplotlib 기본
#
# > 라이브러리 설치
# > - pip install matplotlib
# > - pip install setuptools
# > - pip install koreanize-matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# 한글설정
import koreanize_matplotlib

# %% [markdown]
# ### pyplot 모듈(https://matplotlib.org/stable/tutorials/pyplot.html#sphx-glr-tutorials-pyplot-py)
# #### [실습1] 기본 그래프 작성

# %%
# y축 좌표 설정 / x 축은 0 ~ N-1 로 그려짐 / 선 스타일,마커,색상 기본 형식
plt.plot([-1,1,3,4])
plt.title("그래프")
plt.show()

# %% [markdown]
# #### [실습2] x,y 축 지정

# %%
# [실습2] x,y축 데이터 사용

plt.plot([1,2,3,4],[1,4,9,16])
plt.show()

# %% [markdown]
# #### [실습3] 딕셔너리를 이용한 그래프 작성

# %%
data_dict = {'data_x': [1, 2, 3, 4, 5], 'data_y': [2, 3, 5, 10, 8]}
plt.plot('data_x', 'data_y', data=data_dict)
plt.show()

# %% [markdown]
# #### plot(*args, scalex=True, scaley=True, data=None, **kwargs)
# > <b>**kwargs</b>
# > - https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.plot.html
# >    - Line2D properties ( https://matplotlib.org/stable/api/_as_gen/matplotlib.lines.Line2D.html#matplotlib.lines.Line2D )

# %% [markdown]
# #### [실습5] 선, 마커, 마커 사이즈 지정

# %%
plt.plot([1, 2, 3, 4], linewidth=2,  marker='o', markersize=5)
plt.show()

# %% [markdown]
# #### [실습5] 선, 마커, 마커 스타일, 색상 지정

# %%
plt.plot([1, 2, 3], [1, 2, 3], marker="*", linewidth=2, linestyle="--", color="r")
plt.show()
# Out:
# Running cells with 'Python 3.13.1' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/soldesk/AppData/Local/Programs/Python/Python313/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
plt.plot([1, 2, 3], [1, 2, 3], "r*--", linewidth=2)
plt.show()

# %% [markdown]
# #### [실습6] 포맷 문자열을 이용한 스타일 지정

# %%
plt.plot([1, 2, 3], [1, 2, 3], "r^--")
plt.show()

# %% [markdown]
# ### 라벨, 범례, 주석
#
# #### [실습] 라벨, 범례

# %%
#  라벨, 범례

plt.plot([1,2,3,4,5], color = 'blue', label = 'data1')
plt.legend()
plt.show()

# %%
#  라벨, 범례 - legend() 의 labels 속성 이용

plt.plot([1,2,3,4,5], color = 'blue')
plt.legend(labels= ['data1'])
plt.show()

# %%
x = [1,2,3]
y = [2,4,8]
plt.plot(x, y, label="데이터")
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ### figure - 축(axis), 캔버스(canvas), 제목(title), 범례(legend) 포함

# %%
fig = plt.figure()
fig

# %%
fig, axes = plt.subplots(2, 2)

# %%
axes
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# #### 축 설정
# ##### 1. 이름 설정 - xlabel(), ylabel()

# %%
x = [1,2,3]
y = [2,4,8]
plt.plot(x,y)
plt.title("꺽은선 그래프")
plt.xlabel('X 축')
plt.ylabel('Y 축')
plt.show()

# %% [markdown]
# ### 스타일 지정하기

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

# %% [markdown]
# #### [실습4] 선, 마커 스타일 지정

# %%
x = [1,2,3]
y = [2,4,8]
plt.plot(x,y)
plt.title("꺽은선 그래프")
plt.xlabel('X 축')
plt.ylabel('Y 축')
plt.show()

# %%
fig = plt.figure()

# %%
# Figure 객체 
fig = plt.figure(figsize=(10,5)) 
# super title : 여러개의 그래프를 그릴 때 전체 제목 지정
fig.suptitle("전체 그래프 제목")

# 첫번째 그래프 작성
ax1 = fig.add_subplot(1,2,1) # 1행 2열, 첫번째 컬럼에 차트 위치
ax1.plot(x,y)
ax1.set_title("첫번째")


x1 = [4,5,6]
y1 = [10,12,15]
# # 각 그래프 별 제목 설정
ax2 = fig.add_subplot(1,2,2)  # 1행 2열, 두번째 컬럼에 차트 위치
ax2.plot(x,y,c="r")
ax2.set_title("두번째")
plt.show()
